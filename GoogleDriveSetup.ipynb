# %% [markdown]
# Give Colab access to your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Navigate into your Google Drive.

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# Clone the course repo into your Google Drive.
#
# This will create a new folder called `ursp688y_sp2024` in your Google Drive.

# %%
# !git clone https://github.com/chesterharvey/ursp688y_sp2024.git
# Out:
# fatal: destination path 'ursp688y_sp2024' already exists and is not an empty directory.

# %% [markdown]
# Navigate into the `ursp688y_sp2024` directory.

# %%
# %cd ursp688y_sp2024
# Out:
# /content/drive/MyDrive/ursp688y_sp2024

# %% [markdown]
# Pull any updates into the current directory. (Must be a Git-tracked directory)

# %%
# !git pull
# Out:
# Updating 137ab87..429af89
# Fast-forward
#  .gitignore                                                      |  3 ++
#  .../{Test Homework.ipynb => Homework 01/Homework 01.ipynb}      |  0
#  Homeworks/Homework 02/Homework 02.ipynb                         | 79 +++++++++++++++++++++++++++++
#  Homeworks/{ => Homework 02}/fruit.csv                           |  0
#  4 files changed, 82 insertions(+)
#  rename Homeworks/{Test Homework.ipynb => Homework 01/Homework 01.ipynb} (100%)
#  create mode 100644 Homeworks/Homework 02/Homework 02.ipynb
#  rename Homeworks/{ => Homework 02}/fruit.csv (100%)

# %% [markdown]
# See what directory you are currently in

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ursp688y_sp2024

# %% [markdown]
# Go back one level in the directory structure.

# %%
# %cd ..
# Out:
# /content/drive/MyDrive
